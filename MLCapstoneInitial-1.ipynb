# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
bur = pd.read_csv('MLProject/data/bureau.csv')
bur_bal = pd.read_csv('MLProject/data/bureau_balance.csv')
#crbal = pd.read_csv('MLProject/data/credit_card_balance.csv')
#hcr = pd.read_csv('MLProject/data/HomeCredit_columns_description.csv', encoding='ISO-8859-1')
#inst = pd.read_csv('MLProject/data/installments_payments.csv')
#POS = pd.read_csv('MLProject/data/installments_payments.csv')
#prev = pd.read_csv('MLProject/data/previous_application.csv')
#samp = pd.read_csv('MLProject/data/sample_submission.csv')
#bur.sample(5)
#prev.sample(5)

# %%
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows', None)

# %%
bur.sample(5)
# Out:
#          SK_ID_CURR  SK_ID_BUREAU CREDIT_ACTIVE CREDIT_CURRENCY  DAYS_CREDIT  \
# 1341919      123562       6114488        Closed      currency 1         -992
# 745774       154007       5322272        Closed      currency 1        -1638
# 1181231      203916       5522605        Active      currency 1        -1598
# 942872       404341       6294010        Closed      currency 1        -2570
# 974191       377356       5881496        Active      currency 1        -1316
#
#          CREDIT_DAY_OVERDUE  DAYS_CREDIT_ENDDATE  DAYS_ENDDATE_FACT  \
# 1341919                   0               -776.0             -776.0
# 745774                    0               -907.0             -937.0
# 1181231                   0               1005.0                NaN
# 942872                    0              -2452.0            -2438.0
# 974191                    0                  NaN                NaN
#
#          AMT_CREDIT_MAX_OVERDUE  CNT_CREDIT_PROLONG  AMT_CREDIT_SUM  \
# ...

# %%
bur_bal.sample(5)
# Out:
#           SK_ID_BUREAU  MONTHS_BALANCE STATUS
# 13474819       6159878             -48      C
# 8950082        5137419             -63      X
# 21745958       6189763             -78      0
# 12998673       6804170              -5      C
# 14616610       6243280             -23      X

# %%
bur[bur["SK_ID_CURR"]==169257]
# Out:
#         SK_ID_CURR  SK_ID_BUREAU CREDIT_ACTIVE CREDIT_CURRENCY  DAYS_CREDIT  \
# 406935      169257       6421587        Active      currency 1         -841
# 406936      169257       6421588        Active      currency 1         -400
# 406937      169257       6421589        Closed      currency 1         -593
# 406938      169257       6421590        Closed      currency 1         -964
#
#         CREDIT_DAY_OVERDUE  DAYS_CREDIT_ENDDATE  DAYS_ENDDATE_FACT  \
# 406935                   0                254.0                NaN
# 406936                   0                333.0                NaN
# 406937                   0               -400.0             -400.0
# 406938                   0               -598.0             -598.0
#
#         AMT_CREDIT_MAX_OVERDUE  CNT_CREDIT_PROLONG  AMT_CREDIT_SUM  \
# 406935                     NaN                   0       237150.00
# 406936                     NaN                   0       297000.00
# ...

# %%
bur_joined = pd.merge(bur, bur_bal, on ='SK_ID_BUREAU',how ='inner')

# %%
PastClosedLoans = bur[bur["CREDIT_ACTIVE"]=="Closed"].groupby("SK_ID_CURR").sum()

# %%
PastClosedLoans.iloc[169257]
# Out:
# SK_ID_BUREAU              16016455.0
# DAYS_CREDIT                  -2839.0
# CREDIT_DAY_OVERDUE               0.0
# DAYS_CREDIT_ENDDATE          -1556.0
# DAYS_ENDDATE_FACT            -1743.0
# AMT_CREDIT_MAX_OVERDUE           0.0
# CNT_CREDIT_PROLONG               0.0
# AMT_CREDIT_SUM             1596681.0
# AMT_CREDIT_SUM_DEBT              0.0
# AMT_CREDIT_SUM_LIMIT             0.0
# AMT_CREDIT_SUM_OVERDUE           0.0
# DAYS_CREDIT_UPDATE           -1211.0
# AMT_ANNUITY                      0.0
# Name: 325047, dtype: float64

# %%
PastActiveLoans = bur[bur["CREDIT_ACTIVE"]=="Active"].groupby("SK_ID_CURR").sum()

# %%
PastActiveLoans.iloc[169257]
# Out:
# SK_ID_BUREAU              6586224.0
# DAYS_CREDIT                 -1389.0
# CREDIT_DAY_OVERDUE              0.0
# DAYS_CREDIT_ENDDATE             0.0
# DAYS_ENDDATE_FACT               0.0
# AMT_CREDIT_MAX_OVERDUE       8185.5
# CNT_CREDIT_PROLONG              0.0
# AMT_CREDIT_SUM             180000.0
# AMT_CREDIT_SUM_DEBT        165231.0
# AMT_CREDIT_SUM_LIMIT            0.0
# AMT_CREDIT_SUM_OVERDUE          0.0
# DAYS_CREDIT_UPDATE             -9.0
# AMT_ANNUITY                     0.0
# Name: 339571, dtype: float64

# %%
PastActiveLoans.sample(5)
# Out:
#             SK_ID_BUREAU  DAYS_CREDIT  CREDIT_DAY_OVERDUE  \
# SK_ID_CURR
# 203717          12527935        -1257                   0
# 216683           5259309        -1501                   0
# 168152           5079541          -98                   0
# 380669           5810637         -236                   0
# 357737          25260843        -3269                   0
#
#             DAYS_CREDIT_ENDDATE  DAYS_ENDDATE_FACT  AMT_CREDIT_MAX_OVERDUE  \
# SK_ID_CURR
# 203717                   1794.0                0.0                   0.000
# 216683                  -1197.0                0.0                   0.000
# 168152                    870.0                0.0                   0.000
# 380669                    842.0                0.0                   0.000
# 357737                   1472.0                0.0                6152.625
#
#             CNT_CREDIT_PROLONG  AMT_CREDIT_SUM  AMT_CREDIT_SUM_DEBT  \
# SK_ID_CURR
# ...

# %%
test_set = pd.read_csv('MLProject/data/application_test.csv')

# %%
test_set.sample(4)
# Out:
#        SK_ID_CURR NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  \
# 26183      290634         Cash loans           M            N               Y
# 20219      246807         Cash loans           M            N               Y
# 37045      371013         Cash loans           F            N               N
# 3483       124553         Cash loans           M            Y               N
#
#        CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 26183             1          157500.0    257391.0      27157.5
# 20219             1          180000.0     90000.0      10678.5
# 37045             0           90000.0    651600.0      27738.0
# 3483              0           49500.0    225000.0      11488.5
#
#        AMT_GOODS_PRICE NAME_TYPE_SUITE NAME_INCOME_TYPE  \
# 26183         238500.0   Unaccompanied          Working
# 20219          90000.0   Unaccompanied          Working
# 37045         562500.0   Unaccompanied        Pensioner
# ...

# %%
train_set = pd.read_csv('MLProject/data/application_train.csv')

# %%
train_set.sample(3)
# Out:
#         SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 14994       117508       0         Cash loans           F            N
# 126470      246673       0         Cash loans           M            N
# 284327      429276       0         Cash loans           M            Y
#
#        FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  \
# 14994                N             0          103500.0    474048.0
# 126470               N             2          157500.0    640080.0
# 284327               Y             2          202500.0   1061599.5
#
#         AMT_ANNUITY  AMT_GOODS_PRICE  NAME_TYPE_SUITE NAME_INCOME_TYPE  \
# 14994       20214.0         360000.0    Unaccompanied          Working
# 126470      20227.5         450000.0    Unaccompanied          Working
# 284327      31041.0         927000.0  Spouse, partner          Working
#
#                   NAME_EDUCATION_TYPE    NAME_FAMILY_STATUS  \
# ...

# %%
test_set.columns = test_set.columns.str.lower().str.replace(' ', '_') # A
string_columns = list(test_set.dtypes[test_set.dtypes == 'object'].index) # B
for col in string_columns:
    test_set[col] = test_set[col].str.lower().str.replace(' ', '_') # C
test_set.shape
#test_set.info()
test_set.nunique()
# Out:
# sk_id_curr                      48744
# name_contract_type                  2
# code_gender                         2
# flag_own_car                        2
# flag_own_realty                     2
# cnt_children                       11
# amt_income_total                  606
# amt_credit                       2937
# amt_annuity                      7491
# amt_goods_price                   677
# name_type_suite                     7
# name_income_type                    7
# name_education_type                 5
# name_family_status                  5
# name_housing_type                   6
# region_population_relative         81
# days_birth                      15477
# days_employed                    7863
# days_registration               12618
# days_id_publish                  5880
# own_car_age                        52
# flag_mobil                          2
# flag_emp_phone                      2
# flag_work_phone                     2
# flag_cont_mobile                    2
# ...

# %%
train_set.columns = train_set.columns.str.lower().str.replace(' ', '_') # A
string_columns = list(train_set.dtypes[train_set.dtypes == 'object'].index) # B
for col in string_columns:
    train_set[col] = train_set[col].str.lower().str.replace(' ', '_') # C
train_set.shape
#train_set.info()
train_set.nunique()
# Out:
# sk_id_curr                      307511
# target                               2
# name_contract_type                   2
# code_gender                          3
# flag_own_car                         2
# flag_own_realty                      2
# cnt_children                        15
# amt_income_total                  2548
# amt_credit                        5603
# amt_annuity                      13672
# amt_goods_price                   1002
# name_type_suite                      7
# name_income_type                     8
# name_education_type                  5
# name_family_status                   6
# name_housing_type                    6
# region_population_relative          81
# days_birth                       17460
# days_employed                    12574
# days_registration                15688
# days_id_publish                   6168
# own_car_age                         62
# flag_mobil                           2
# flag_emp_phone                       2
# ...

# %%
test_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48744 entries, 0 to 48743
# Columns: 121 entries, sk_id_curr to amt_req_credit_bureau_year
# dtypes: float64(65), int64(40), object(16)
# memory usage: 45.0+ MB

# %%
train_set.info(max_cols=122)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307511 entries, 0 to 307510
# Data columns (total 122 columns):
#  #    Column                        Non-Null Count   Dtype
# ---   ------                        --------------   -----
#  0    sk_id_curr                    307511 non-null  int64
#  1    target                        307511 non-null  int64
#  2    name_contract_type            307511 non-null  object
#  3    code_gender                   307511 non-null  object
#  4    flag_own_car                  307511 non-null  object
#  5    flag_own_realty               307511 non-null  object
#  6    cnt_children                  307511 non-null  int64
#  7    amt_income_total              307511 non-null  float64
#  8    amt_credit                    307511 non-null  float64
#  9    amt_annuity                   307499 non-null  float64
#  10   amt_goods_price               307233 non-null  float64
#  11   name_type_suite               306219 non-null  object
# ...

# %%
test_set.dtypes
# Out:
# sk_id_curr                        int64
# name_contract_type               object
# code_gender                      object
# flag_own_car                     object
# flag_own_realty                  object
# cnt_children                      int64
# amt_income_total                float64
# amt_credit                      float64
# amt_annuity                     float64
# amt_goods_price                 float64
# name_type_suite                  object
# name_income_type                 object
# name_education_type              object
# name_family_status               object
# name_housing_type                object
# region_population_relative      float64
# days_birth                        int64
# days_employed                     int64
# days_registration               float64
# days_id_publish                   int64
# own_car_age                     float64
# flag_mobil                        int64
# flag_emp_phone                    int64
# ...

# %%
#corr = train_set.corr()
#sns.heatmap(corr)
# plt.figure(figsize=(3,3), dpi=100)
#plt.gcf().set_size_inches(20, 10)#
#plt.show()

# %%
#train_set.isnull().sum()

# %%
#test_set.isnull().sum()

# %%
train_set.dtypes.value_counts()
# Out:
# float64    65
# int64      41
# object     16
# dtype: int64

# %%
train_set.dtypes
# Out:
# sk_id_curr                        int64
# target                            int64
# name_contract_type               object
# code_gender                      object
# flag_own_car                     object
# flag_own_realty                  object
# cnt_children                      int64
# amt_income_total                float64
# amt_credit                      float64
# amt_annuity                     float64
# amt_goods_price                 float64
# name_type_suite                  object
# name_income_type                 object
# name_education_type              object
# name_family_status               object
# name_housing_type                object
# region_population_relative      float64
# days_birth                        int64
# days_employed                     int64
# days_registration               float64
# days_id_publish                   int64
# own_car_age                     float64
# flag_mobil                        int64
# ...

# %%
#Categorical data unique values for each categorical item 
train_set.select_dtypes(include=[object]).apply(pd.Series.nunique, axis = 0)
# Out:
# name_contract_type             2
# code_gender                    3
# flag_own_car                   2
# flag_own_realty                2
# name_type_suite                7
# name_income_type               8
# name_education_type            5
# name_family_status             6
# name_housing_type              6
# occupation_type               18
# weekday_appr_process_start     7
# organization_type             58
# fondkapremont_mode             4
# housetype_mode                 3
# wallsmaterial_mode             7
# emergencystate_mode            2
# dtype: int64

# %%
#Target Value distribution ( 0: Repays loan on time , 1: has difficulty in repaying loan on time)
train_set.target.value_counts()
# Out:
# 0    282686
# 1     24825
# Name: target, dtype: int64

# %%
#Categorical data unique values for each categorical item 
train_set.select_dtypes("object")

# %%
#Finding columns with most missing or null values 
train_set.isnull().sum().sort_values(ascending=False).head(20)
# Out:
# commonarea_medi             214865
# commonarea_avg              214865
# commonarea_mode             214865
# nonlivingapartments_mode    213514
# nonlivingapartments_avg     213514
# nonlivingapartments_medi    213514
# fondkapremont_mode          210295
# livingapartments_mode       210199
# livingapartments_avg        210199
# livingapartments_medi       210199
# floorsmin_avg               208642
# floorsmin_mode              208642
# floorsmin_medi              208642
# years_build_medi            204488
# years_build_mode            204488
# years_build_avg             204488
# own_car_age                 202929
# landarea_medi               182590
# landarea_mode               182590
# landarea_avg                182590
# dtype: int64

# %%
#train_set.describe()
# Out:
#           sk_id_curr         target   cnt_children  amt_income_total  \
# count  307511.000000  307511.000000  307511.000000      3.075110e+05
# mean   278180.518577       0.080729       0.417052      1.687979e+05
# std    102790.175348       0.272419       0.722121      2.371231e+05
# min    100002.000000       0.000000       0.000000      2.565000e+04
# 25%    189145.500000       0.000000       0.000000      1.125000e+05
# 50%    278202.000000       0.000000       0.000000      1.471500e+05
# 75%    367142.500000       0.000000       1.000000      2.025000e+05
# max    456255.000000       1.000000      19.000000      1.170000e+08
#
#          amt_credit    amt_annuity  amt_goods_price  \
# count  3.075110e+05  307499.000000     3.072330e+05
# mean   5.990260e+05   27108.573909     5.383962e+05
# std    4.024908e+05   14493.737315     3.694465e+05
# min    4.500000e+04    1615.500000     4.050000e+04
# 25%    2.700000e+05   16524.000000     2.385000e+05
# ...

# %%
#train_set.fillna(-999)

# %%
train_set.sample(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11900/4279188159.py in <module>
# ----> 1 train_set.sample(5)
#
# NameError: name 'train_set' is not defined
